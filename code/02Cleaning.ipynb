# %% [markdown]
# ### Data Cleaning
# Let's start the process of data cleaning. The purpose behind this step is to prepare our dataset for use in our machine learning model. By cleaning the data, we aim to reduce the potential for errors and enhance the model's ability to make accurate predictions. This initial phase is crucial as it sets the foundation for the success of our machine learning .

# %%
import pandas as pd

# %%
# Load the data
df = pd.read_csv(r"C:/Users/Alex/Desktop/TKH Files/TKH TLabs/data/Fraud.csv")
df
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT     9839.64  C1231006815      170136.00
# 1           1   PAYMENT     1864.28  C1666544295       21249.00
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 4           1   PAYMENT    11668.14  C2048537720       41554.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00        0
# ...

# %% [markdown]
# We will drop columns that are not necessary for our machine learning model to streamline the dataset for analysis.

# %% [markdown]
# We will begin by dropping the columns 'nameOrig' and 'nameDest'. These columns are being removed because they are not as useful for our machine learning model and could potentially interfere with its performance.

# %%
df.drop(['nameOrig','nameDest'], axis=1, inplace=True)
df
# Out:
#          step      type      amount  oldbalanceOrg  newbalanceOrig  \
# 0           1   PAYMENT     9839.64      170136.00       160296.36
# 1           1   PAYMENT     1864.28       21249.00        19384.72
# 2           1  TRANSFER      181.00         181.00            0.00
# 3           1  CASH_OUT      181.00         181.00            0.00
# 4           1   PAYMENT    11668.14       41554.00        29885.86
# ...       ...       ...         ...            ...             ...
# 6362615   743  CASH_OUT   339682.13      339682.13            0.00
# 6362616   743  TRANSFER  6311409.28     6311409.28            0.00
# 6362617   743  CASH_OUT  6311409.28     6311409.28            0.00
# 6362618   743  TRANSFER   850002.52      850002.52            0.00
# 6362619   743  CASH_OUT   850002.52      850002.52            0.00
#
#          oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0                  0.00            0.00        0               0
# ...

# %% [markdown]
# We are also going to drop the column isflaggedfraud since in our eda it did not seem to have much of an impact in our data additionally we are also going to drop isFraud and we are going to make a different one so we can use it in our machine learning model so there wont be any bias in the outcome

# %%
df.drop(['isFlaggedFraud'], axis=1, inplace=True)

# %%
df.head(20)
# Out:
#     step      type     amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# 0      1   PAYMENT    9839.64      170136.00       160296.36             0.0
# 1      1   PAYMENT    1864.28       21249.00        19384.72             0.0
# 2      1  TRANSFER     181.00         181.00            0.00             0.0
# 3      1  CASH_OUT     181.00         181.00            0.00         21182.0
# 4      1   PAYMENT   11668.14       41554.00        29885.86             0.0
# 5      1   PAYMENT    7817.71       53860.00        46042.29             0.0
# 6      1   PAYMENT    7107.77      183195.00       176087.23             0.0
# 7      1   PAYMENT    7861.64      176087.23       168225.59             0.0
# 8      1   PAYMENT    4024.36        2671.00            0.00             0.0
# 9      1     DEBIT    5337.77       41720.00        36382.23         41898.0
# 10     1     DEBIT    9644.94        4465.00            0.00         10845.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 8 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            object
#  2   amount          float64
#  3   oldbalanceOrg   float64
#  4   newbalanceOrig  float64
#  5   oldbalanceDest  float64
#  6   newbalanceDest  float64
#  7   isFraud         int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 388.3+ MB

# %%
df.to_csv('cleaned_data', index= False)
